# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import pickle
df=pd.read_csv("/home/user/Downloads/Telco-Customer-Churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
print(df.shape)
# Out:
# (7043, 21)

# %%
print(df.dtypes)
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# <h4> input:customer features</h4>
# <h4>Output:chrun probability yes (or)no</h4>

# %%
df.isna()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
#dropping the customerID column as this is not required for modeling
df=df.drop(columns=['customerID'])

# %%
df.head(5)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
#print the unique values in the all the columns
numerical_feature=['tenure','TotalCharges','MonthlyCharges']
for col in df.columns:
    if col not in numerical_feature:
        print(col,df[col].unique())
        print("."*50)
# Out:
# gender ['Female' 'Male']
# ..................................................
# SeniorCitizen [0 1]
# ..................................................
# Partner ['Yes' 'No']
# ..................................................
# Dependents ['No' 'Yes']
# ..................................................
# PhoneService ['No' 'Yes']
# ..................................................
# MultipleLines ['No phone service' 'No' 'Yes']
# ..................................................
# InternetService ['DSL' 'Fiber optic' 'No']
# ..................................................
# OnlineSecurity ['No' 'Yes' 'No internet service']
# ..................................................
# OnlineBackup ['Yes' 'No' 'No internet service']
# ..................................................
# DeviceProtection ['No' 'Yes' 'No internet service']
# ..................................................
# TechSupport ['No' 'Yes' 'No internet service']
# ...

# %% [markdown]
# <h5> excepting the total charges must be in floating point numbers but it is in the  object</h5>
# <h5> convertion of the object to floating points</h5>

# %%
df[df['TotalCharges']==' ']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df['TotalCharges']=df['TotalCharges'].replace({" ":"0.0"})

# %%
df['TotalCharges']=df['TotalCharges'].astype(float)
df.info
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
#checking the class distributuin of the target column
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
sns.countplot(x='Churn',data=df)
plt.title("churn distribution")
# Out:
# Text(0.5, 1.0, 'churn distribution')

# %% [markdown]
# <h5> Here we clearly notices that imbalanced in dataset</h5>
# <h5> so ,we cannot directly train a model</h5>

# %% [markdown]
# <h3> insights:</h3>
# <p> 1.Customer Id is removed becauuse it is not required for monitoring</p>
# <p>2.NO missing values</p>
# <p> 3.Missing values in the totalCharges column and replaced with zeros</p>
# <p>4.class imbalanced identified in the target</p>

# %% [markdown]
# <h3> Numerical Feature Anlaysis</h3>
# <h5> Understand the Distributuin of the NUmerical Values</h5>

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0              Yes  Electronic check           29.85         29.85    No
# 1               No      Mailed check           56.95       1889.50    No

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
def plot_histogram(df,column_name):
    plt.figure(figsize=(5,3))
    sns.histplot(df[column_name],kde=True)
    plt.title(f'distributuin of {column_name}')
    col_mean=df[column_name].mean()
    col_median=df[column_name].median()
    #add vertical lines on  for the mean and median
    plt.axvline(col_mean,color='red',linestyle='--',label='mean')
    plt.axvline(col_median,color='green',linestyle='--',label='median')
    plt.legend()
    plt.show()

# %%
plot_histogram(df,"tenure")
df['tenure'].value_counts()
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64

# %%
plot_histogram(df,'TotalCharges')

# %%
plot_histogram(df,"MonthlyCharges")

# %%
def box_plot(df,column_name):
    plt.figure(figsize=(5,4))
    sns.boxplot(y=df[column_name])
    plt.title(f'Box-plot of {column_name}')
    plt.ylabel(f'{column_name}')
    plt.show()

# %%
box_plot(df,'TotalCharges')

# %%
MonthlyCharges=box_plot(df,'MonthlyCharges')

# %%
box_plot(df,"tenure")
df['tenure'].value_counts()
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64

# %%
df['Churn']=df['Churn'].replace({'Yes':'1','No':'0'})
df['Churn']=df['Churn'].astype(int)

# %% [markdown]
# # correlation heatmap for numerical analysis

# %%
plt.figure(figsize=(6,5))
plt.title("correlation between numerical column")
sns.heatmap(df[['TotalCharges','MonthlyCharges','tenure']].corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: title={'center': 'correlation between numerical column'}>

# %% [markdown]
# # insights
# <p>1.there is no outliers</p>
# <p>2.see the relationship between the numerical columns</p>
# <p>3.seeing the distribution among the numericla columns</p>

# %% [markdown]
# # categorial analysis

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object

# %%
obj_cols=df.select_dtypes(include='object').columns.to_list()
obj_cols=['SeniorCitizen']+obj_cols+['Churn']
for col in obj_cols:
    plt.figure(figsize=(5,3))
    sns.countplot(x=df[col])
    plt.title(f"count plot {col}")
    plt.show()

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# # Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
obj_cols=df.select_dtypes(include='object').columns
print(obj_cols)
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod'],
#       dtype='object')

# %%
#intialize the a dictionary to save the encoders
encoder={}
import pickle
for col in obj_cols:
    e=LabelEncoder()
    df[col]=e.fit_transform(df[col])
    encoder[col]=e

#save the encoders to a pickle file
with open('encoder.pkl','wb') as f:
    pickle.dump(encoder,f)

# %%
encoder
# Out:
# {'gender': LabelEncoder(),
#  'Partner': LabelEncoder(),
#  'Dependents': LabelEncoder(),
#  'PhoneService': LabelEncoder(),
#  'MultipleLines': LabelEncoder(),
#  'InternetService': LabelEncoder(),
#  'OnlineSecurity': LabelEncoder(),
#  'OnlineBackup': LabelEncoder(),
#  'DeviceProtection': LabelEncoder(),
#  'TechSupport': LabelEncoder(),
#  'StreamingTV': LabelEncoder(),
#  'StreamingMovies': LabelEncoder(),
#  'Contract': LabelEncoder(),
#  'PaperlessBilling': LabelEncoder(),
#  'PaymentMethod': LabelEncoder()}

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %% [markdown]
# # handling the imbalanced data in target column

# %% [markdown]
# <h4> Training and split</h4>

# %%
x=df.drop(columns=['Churn'])
y=df['Churn']

# %%
x
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int64

# %%
#spilt the training and test data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(y_train.shape)
# Out:
# (5634,)

# %%
smote=SMOTE(random_state=42)

# %%
x_train_smote,y_train_smote=smote.fit_resample(x_train,y_train)

# %%
print(y_train_smote.shape)
# Out:
# (8276,)

# %%
print(y_train.value_counts())
# Out:
# Churn
# 0    4138
# 1    1496
# Name: count, dtype: int64

# %%
print(y_train_smote.value_counts())
# Out:
# Churn
# 0    4138
# 1    4138
# Name: count, dtype: int64

# %% [markdown]
# # Model Training

# %%
from xgboost import XGBClassifier

# %%
#dictionary of models
models={
    'Decision Tree':DecisionTreeClassifier(random_state=42),
    'Random Forest':RandomForestClassifier(random_state=42),
    'XGBoost':XGBClassifier(random_state=42)
}

# %%
#dictionary to store the cross validations results
cv_score={}

#perform a 5 fold cross validations for the model
for model_name,model in models.items():
    print(f"Training {model_name} with the default parameters")
    scores=cross_val_score(model,x_train_smote,y_train_smote,cv=5,scoring='accuracy')
    cv_score[model_name]=scores
    print(f"{model_name} cross-validation accuracy:{np.mean(scores):.2f}")
    print("."*50)
# Out:
# Training Decision Tree with the default parameters
# Decision Tree cross-validation accuracy:0.78
# ..................................................
# Training Random Forest with the default parameters
# Random Forest cross-validation accuracy:0.84
# ..................................................
# Training XGBoost with the default parameters
# XGBoost cross-validation accuracy:0.83
# ..................................................

# %%
cv_score
# Out:
# {'Decision Tree': array([0.68297101, 0.71601208, 0.81993958, 0.83564955, 0.83746224]),
#  'Random Forest': array([0.72826087, 0.7734139 , 0.90332326, 0.89969789, 0.8978852 ]),
#  'XGBoost': array([0.71135266, 0.74864048, 0.91178248, 0.88640483, 0.91117825])}

# %% [markdown]
# # Random Forest gives the higher accuracy compared to the models with the default parameters

# %%
rfc=RandomForestClassifier(random_state=42)

# %%
rfc.fit(x_train_smote,y_train_smote)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# # model evalution

# %%
print(y_test.value_counts())
# Out:
# Churn
# 0    1036
# 1     373
# Name: count, dtype: int64

# %%
#evaluate on test data
y_test_pred=model.predict(x_test)
print("Accuracy Score:\n",accuracy_score(y_test,y_test_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_test_pred))
print("Classification Report:\n",classification_report(y_test,y_test_pred))
# Out:
# Accuracy Score:
#  0.7821149751596878
# Confusion Matrix:
#  [[882 154]
#  [153 220]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1036
#            1       0.59      0.59      0.59       373
#
#     accuracy                           0.78      1409
#    macro avg       0.72      0.72      0.72      1409
# weighted avg       0.78      0.78      0.78      1409

# %%
#save the trained model as a pickle file
model_data={"model":rfc,"features_names":x.columns.tolist()}
with open('customer_chrun_model.pkl','wb') as f:
    pickle.dump(model_data,f)

# %% [markdown]
# # load the saved model and build the prediction system

# %%
#load the saved model and with the feature names
with open('customer_chrun_model.pkl',"rb") as f:
    model_data=pickle.load(f)
    
loaded_model=model_data['model']
features_names=model_data['features_names']

# %%
print(loaded_model)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print(features_names)
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges']

# %%
input_data={
    'gender':'Female',
    'SeniorCitizen':0,
    'Partner':'Yes',
    'Dependents':'No',
    'tenure':1,
    'PhoneService':'No',
    'MultipleLines':'No phone service',
    'InternetService':'DSL',
    'OnlineSecurity':'No',
    'OnlineBackup':'Yes',
    'DeviceProtection':'No',
    'TechSupport':'No',
    'StreamingTV':'No',
    'StreamingMovies':'No',
    'Contract':'Month-to-month',
    'PaperlessBilling':'Yes',
    'PaymentMethod':'Electronic check',
    'MonthlyCharges':29.85, 
    'TotalCharges':29.85
}
df1=pd.DataFrame([input_data])
with open('encoder.pkl','rb') as f:
    encoders=pickle.load(f)
print(df1.head())
for column,encoder in encoders.items():
    df1[column]=encoder.transform(df1[column])
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges
# 0              Yes  Electronic check           29.85         29.85

# %%
df1
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
#
#    PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges
# 0                 1              2           29.85         29.85

# %%
#make a prediction 
prediction=model.predict(df1)
print(prediction)
result="Churn" if prediction[0]==1 else "No Churn"
print(f"Prediction:{result}")
# Out:
# [0]
# Prediction:No Churn
